# %%
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 KB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 5.7 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached idna-3.7-py3-none-any.whl (66 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 7.2 MB/s eta 0:00:00a 0:00:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 7.4 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("cd-vjumk").project("light-njqzl")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to light-4 in yolov8:: 100%|██████████| 104/104 [00:00<00:00, 16247.30it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("m1n5eo").project("hw3-1-m1mw7")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to hw3-1-3 in yolov8:: 100%|██████████| 82/82 [00:00<00:00, 14332.33it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("m1n5eo").project("hw3-1-m1mw7")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to hw3-1-2 in yolov8:: 100%|██████████| 82/82 [00:00<00:00, 13601.18it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("m1n5eo").project("hw3-1-m1mw7")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to hw3-1-1 in yolov8:: 100%|██████████| 76/76 [00:00<00:00, 11423.71it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("faasky").project("traffic-light-m1ev8")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Traffic-Light-1 in yolov8:: 100%|██████████| 112/112 [00:00<00:00, 15680.69it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("traffic-final").project("traffic-signs-aaspe")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to traffic-signs-3 in yolov8:: 100%|██████████| 9246/9246 [00:00<00:00, 16113.82it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("psyshow").project("people-and-car")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to people-and-car-3 in yolov8:: 100%|██████████| 7058/7058 [00:00<00:00, 14765.04it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("naeman").project("person-and-car-txy2k")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to person-and-car-1 in yolov8:: 100%|██████████| 2502/2502 [00:00<00:00, 14217.19it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("abner").project("person-hgivm")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to person-3 in yolov8:: 100%|██████████| 2977/2977 [00:00<00:00, 11544.16it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("kamel-elsehly").project("vehicle-detection-yolo-v5")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Vehicle-Detection-YOLO-V5-1 in yolov8:: 100%|██████████| 3070/3070 [00:00<00:00, 19687.53it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("falldetction").project("traffic-lights-tyekw")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to traffic-lights-1 in yolov8:: 100%|██████████| 570/570 [00:00<00:00, 8762.73it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("car-detection-qw1rz").project("traffic-lights-yzdlz")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("college-of-engineering-pune").project("person-cv9ij")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to person-1 in yolov8:: 100%|██████████| 432/432 [00:00<00:00, 15778.36it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("iot-7qo9b").project("person-nihxx")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to person-2 in yolov8:: 100%|██████████| 743/743 [00:00<00:00, 12497.57it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("vinsen").project("person-vva78")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("sagemcom-jifgx").project("vehicle-u2wys")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to vehicle-1 in yolov8:: 100%|██████████| 12912/12912 [00:00<00:00, 19422.51it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("jasir-k").project("vehicle-2lw3x")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Vehicle-1 in yolov8:: 100%|██████████| 1266/1266 [00:00<00:00, 14679.67it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("object-detection-jgyjj").project("vehicle-yp69e")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to vehicle-3 in yolov8:: 100%|██████████| 600/600 [00:00<00:00, 15531.30it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("bnyamin-dikici576").project("traffic-signs-fpijv")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Traffic-Signs-1 in yolov8:: 100%|██████████| 4214/4214 [00:00<00:00, 16030.08it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("frank-yu").project("traffic-signs-2cv9s")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Traffic-signs-1 in yolov8:: 100%|██████████| 1762/1762 [00:00<00:00, 19140.76it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("pruebas-de-200").project("traffic-light-green-vvbbt")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Traffic-light-green-1 in yolov8:: 100%|██████████| 406/406 [00:00<00:00, 1787.65it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("andres-pjrn7").project("green-light-dmrwu")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Green-light-1 in yolov8:: 100%|██████████| 489/489 [00:00<00:00, 5514.49it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("trafficlightdetect").project("traffic-light-ke5b5")
version = project.version(10)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Traffic-light-10 in yolov8:: 100%|██████████| 2012/2012 [00:00<00:00, 4127.91it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("trafficlightdetect").project("traffic-light-ke5b5")
version = project.version(8)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Traffic-light-8 in yolov8:: 100%|██████████| 2012/2012 [00:01<00:00, 1573.41it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("trafficlightdetect").project("traffic-light-ke5b5")
version = project.version(7)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Traffic-light-7 in yolov8:: 100%|██████████| 1268/1268 [00:00<00:00, 2172.56it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("trafficlightdetect").project("traffic-light-ke5b5")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Traffic-light-6 in yolov8:: 100%|██████████| 470/470 [00:00<00:00, 3958.22it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("trafficlightdetect").project("traffic-light-ke5b5")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Traffic-light-1 in yolov8:: 100%|██████████| 126/126 [00:00<00:00, 5256.02it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("pruebas-0f3uc").project("traffic-light-red-co5xj")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Traffic-light-red-1 in yolov8:: 100%|██████████| 406/406 [00:00<00:00, 982.61it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("poomlak-promdontri-nrdoj").project("traffic-wqvin")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to traffic-4 in yolov8:: 100%|██████████| 168/168 [00:00<00:00, 3923.32it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("poomlak-promdontri-nrdoj").project("traffic-wqvin")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to traffic-3 in yolov8:: 100%|██████████| 168/168 [00:00<00:00, 3056.22it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("poomlak-promdontri-nrdoj").project("traffic-wqvin")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to traffic-2 in yolov8:: 100%|██████████| 168/168 [00:00<00:00, 2780.40it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("poomlak-promdontri-nrdoj").project("traffic-wqvin")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to traffic-1 in yolov8:: 100%|██████████| 168/168 [00:00<00:00, 3441.92it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HrDuzGXn1RcKeaUSvuX8")
project = rf.workspace("aiclasss").project("traffic-light-ei7t9")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to traffic-light-1 in yolov8:: 100%|██████████| 986/986 [00:00<00:00, 5569.54it/s]
